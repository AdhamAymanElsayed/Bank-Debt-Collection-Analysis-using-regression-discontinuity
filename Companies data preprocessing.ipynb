# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
df = pd.read_csv('companies.csv')
df.head()
# Out:
#         id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0      c:1             0     Company          1        NaN
# 1     c:10             1     Company         10        NaN
# 2    c:100             2     Company        100        NaN
# 3  c:10000             3     Company      10000        NaN
# 4  c:10001             4     Company      10001        NaN
#
#                  name     normalized_name                    permalink  \
# 0            Wetpaint            wetpaint            /company/wetpaint
# 1             Flektor             flektor             /company/flektor
# 2               There               there               /company/there
# 3             MYWEBBO             mywebbo             /company/mywebbo
# 4  THE Movie Streamer  the movie streamer  /company/the-movie-streamer
#
#      category_code     status  ... first_milestone_at last_milestone_at  \
# 0              web  operating  ...         2010-09-05        2013-09-18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196553 entries, 0 to 196552
# Data columns (total 44 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   196553 non-null  object
#  1   Unnamed: 0.1         196553 non-null  int64
#  2   entity_type          196553 non-null  object
#  3   entity_id            196553 non-null  int64
#  4   parent_id            0 non-null       float64
#  5   name                 196531 non-null  object
#  6   normalized_name      196527 non-null  object
#  7   permalink            196553 non-null  object
#  8   category_code        123186 non-null  object
#  9   status               196553 non-null  object
#  10  founded_at           91227 non-null   object
#  11  closed_at            2620 non-null    object
#  12  domain               126545 non-null  object
#  13  homepage_url         126545 non-null  object
#  14  twitter_username     80591 non-null   object
# ...

# %%
df.describe(include='O')
# Out:
#             id entity_type    name normalized_name           permalink  \
# count   196553      196553  196531          196527              196553
# unique  196553           1  196348          195451              196512
# top        c:1     Company       L               l  /company/bboescape
# freq         1      196553       8               9                   3
#
#        category_code     status  founded_at   closed_at            domain  \
# count         123186     196553       91227        2620            126545
# unique            42          4        6156         925            125498
# top         software  operating  2011-01-01  2012-01-01  placeshilton.com
# freq           17922     183441        3748         176                44
#
#         ...   region first_investment_at last_investment_at first_funding_at  \
# count   ...   196553                2583               2583            31507
# unique  ...     5847                1197               1105             3208
# ...

# %%
# rows that have almost values are unique then, not affected the data
df.drop(columns=['Unnamed: 0.1','id','normalized_name','permalink','twitter_username',
                'homepage_url','entity_id','lng','lat'], inplace= True)

# %%
df.head().T
# Out:
#                                                                      0  \
# entity_type                                                    Company
# parent_id                                                          NaN
# name                                                          Wetpaint
# category_code                                                      web
# status                                                       operating
# founded_at                                                  2005-10-17
# closed_at                                                          NaN
# domain                                                wetpaint-inc.com
# logo_url             http://s3.amazonaws.com/crunchbase_prod_assets...
# logo_width                                                       401.0
# logo_height                                                       54.0
# short_description                                                  NaN
# ...

# %%
df['founded_at'] = pd.to_datetime(df['founded_at'], errors='coerce')
current_year = dt.datetime.now().year
df['company_age'] = current_year - df['founded_at'].dt.year

# %%
# Percantage of null Values 
((df.isna().sum()) / df.shape[0])*100
# Out:
# entity_type              0.000000
# parent_id              100.000000
# name                     0.011193
# category_code           37.326828
# status                   0.000000
# founded_at              53.586564
# closed_at               98.667026
# domain                  35.617874
# logo_url                43.979486
# logo_width              43.979486
# logo_height             43.979486
# short_description       96.371971
# description             53.168865
# overview                35.401139
# tag_list                58.559778
# country_code            55.233448
# state_code              74.102151
# city                    57.319400
# region                   0.000000
# first_investment_at     98.685851
# last_investment_at      98.685851
# investment_rounds       98.681780
# invested_companies      98.681780
# first_funding_at        83.970227
# last_funding_at         83.970227
# funding_rounds          83.868473
# funding_total_usd       85.818583
# ...

# %%
# Columns wih null Values Greater than 70% will be dropped
df.drop(columns= ['ROI','funding_total_usd','funding_rounds','last_funding_at',
                  'first_investment_at','last_investment_at','investment_rounds','invested_companies'
                  ,'first_funding_at','state_code','parent_id','closed_at','short_description','founded_at'],inplace=True)

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(inplace=True)

# %%
#drop it , not affected the model becauese only one type in data
df.drop(columns=['entity_type'],inplace=True)

# %%
df.describe(include='O')
# Out:
#           name category_code     status            domain  \
# count   196529        123186     196551            126545
# unique  196348            42          4            125498
# top          L      software  operating  placeshilton.com
# freq         8         17922     183439                44
#
#                                                  logo_url  \
# count                                              110110
# unique                                             110110
# top     http://s3.amazonaws.com/crunchbase_prod_assets...
# freq                                                    1
#
#                            description overview  \
# count                            92048   126971
# unique                           83696   126515
# top     Garage Door Repair/Replacement       We
# freq                               144       40
#
#                                                  tag_list country_code  \
# ...

# %%
(len(df[df['region']== 'unknown']) / df.shape[0]) * 100
# Out:
# 55.895925230601726

# %%
df.head()
# Out:
#                  name    category_code     status                domain  \
# 0            Wetpaint              web  operating      wetpaint-inc.com
# 1             Flektor      games_video   acquired           flektor.com
# 2               There      games_video   acquired             there.com
# 3             MYWEBBO  network_hosting  operating           mywebbo.com
# 4  THE Movie Streamer      games_video  operating  themoviestreamer.com
#
#                                             logo_url  logo_width  logo_height  \
# 0  http://s3.amazonaws.com/crunchbase_prod_assets...       401.0         54.0
# 1  http://s3.amazonaws.com/crunchbase_prod_assets...       186.0         85.0
# 2  http://s3.amazonaws.com/crunchbase_prod_assets...       107.0         34.0
# 3                                                NaN         NaN          NaN
# 4  http://s3.amazonaws.com/crunchbase_prod_assets...       200.0         74.0
#
#                    description  \
# ...

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
df['updated_at'] = pd.to_datetime(df['updated_at'])
df['first_milestone_at'] = pd.to_datetime(df['first_milestone_at'])
df['last_milestone_at'] = pd.to_datetime(df['last_milestone_at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 196551 entries, 0 to 196552
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   name                196529 non-null  object
#  1   category_code       123186 non-null  object
#  2   status              196551 non-null  object
#  3   domain              126545 non-null  object
#  4   logo_url            110110 non-null  object
#  5   logo_width          110110 non-null  float64
#  6   logo_height         110110 non-null  float64
#  7   description         92048 non-null   object
#  8   overview            126971 non-null  object
#  9   tag_list            81452 non-null   object
#  10  country_code        87990 non-null   object
#  11  city                83890 non-null   object
#  12  region              196551 non-null  object
#  13  first_milestone_at  91699 non-null   datetime64[ns]
#  14  last_milestone_at   91699 non-null   datetime64[ns]
# ...

# %%
df.head()
# Out:
#                  name    category_code     status                domain  \
# 0            Wetpaint              web  operating      wetpaint-inc.com
# 1             Flektor      games_video   acquired           flektor.com
# 2               There      games_video   acquired             there.com
# 3             MYWEBBO  network_hosting  operating           mywebbo.com
# 4  THE Movie Streamer      games_video  operating  themoviestreamer.com
#
#                                             logo_url  logo_width  logo_height  \
# 0  http://s3.amazonaws.com/crunchbase_prod_assets...       401.0         54.0
# 1  http://s3.amazonaws.com/crunchbase_prod_assets...       186.0         85.0
# 2  http://s3.amazonaws.com/crunchbase_prod_assets...       107.0         34.0
# 3                                                NaN         NaN          NaN
# 4  http://s3.amazonaws.com/crunchbase_prod_assets...       200.0         74.0
#
#                    description  \
# ...

# %%
df.groupby(['country_code'])['city'].value_counts().to_frame()
# Out:
#                         city
# country_code city
# AFG          Kabul         2
#              AE            1
#              APO AE        1
#              Bellevue      1
#              Cerritos      1
# ...                      ...
# ZAF          Zimbali       1
#              cape town     1
# ZMB          Lusaka        2
# ZWE          Harare        3
#              Marondera     1
#
# [11215 rows x 1 columns]
